# %%
# STUDENT MANAGEMENT SYSTEM
# CREATE CLASS "Student"
class Student:
    
    # Constructor
    def __init__(self,Name,Age,Gender,Dob,Seatno):
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.Dob = Dob
        self.Seatno = Seatno
        
        
    # Funtion to create and append students details
    def accept(self,NAME,AGE,GENDER,DOB,SEATNO):
        obj = Student(NAME,AGE,GENDER,DOB,SEATNO)
        Studentlist.append(obj)
        
        
    # Funtion to display Student details
    def display(self,obj):
        print("Name  : ",obj.Name)
        print("Age  : ",obj.Age)
        print("Gender  : ",obj.Gender)
        print("Dob  : ",obj.Dob)
        print("Seatno  : ",obj.Seatno)
        print("\n")
        
        
        
    # Function to search for Student data
    def search(self, n):
        for i in range(Studentlist.__len__()):
            if (Studentlist[i].Name == n):
                return i
            
            
            
    # Funtion to delete Student data 
    def delete(self,n):
        i = obj.search(n)
        del Studentlist[i]
        
        
    # Funtion to update student details
    def update(self , n, No):
        i = obj.search(n)
        NAME = No
        Studentlist[i].Name = NAME;
        
        
# Creating List to add Student Details
Studentlist = []
# Creating of Student Class
obj = Student('',0,'',0,0)

# Displaying Operational options

print("\n Operation Used ,")
print('''\n1.Accept Student Details.\n2.Display Student Details.
3.Search Details Of A Student.\n4.Delete Student Data.
5.Update Student Details.\n6.Exit
''')

# prompting user to input operation choice
X = input('Please enter Y to edit student details or N to quit : ')
X = X.upper()

# Conditions
while X == 'Y':
    ch = int(input('Please choose your operation command : ' ))
    if (ch == 1):
        obj.accept('Ada', 18 ,'F',2014_06_28, 1)
        obj.accept('Sophia', 20 ,'F',1998_01_14, 2)
        obj.accept('Peter', 21 ,'M',1999_06_28, 3)
        obj.accept('Clement', 21 ,'M',1990_06_24,4)
        
        
    elif (ch== 2):
        print('\n')
        print('\nList Of Students')
        for i in range(Studentlist.__len__()):
            obj.display(Studentlist[i])
            
            
            
    elif (ch == 3):
        print('\nStudent Found')
        n = obj.search('Ada')
        obj.display(Studentlist[n])
        
        
        
    elif (ch == 4):
        obj.delete('Clement')
        print(Studentlist.__len__())
        print('List After Deletion :')
        for i in range(Studentlist.__len__()):
            obj.display(Studentlist[i])
            
            
    elif (ch == 5):
        obj.update('Peter','Peterson')
        print(Studentlist.__len__())
        print('List After update :')
        for i in range(Studentlist.__len__()):
            obj.display(Studentlist[i])
            
            
            
    else:
        print("You have entered a wrong choice please try again")
        
        X = input('Please enter Y to edit student details or N to quit : ')
        X = X.upper()
        ch = int(input('Please choose your operation command : ' ))
        
n = 1
# Out:
#  Operation Used ,
#
# 1.Accept Student Details.
# 2.Display Student Details.
# 3.Search Details Of A Student.
# 4.Delete Student Data.
# 5.Update Student Details.
# 6.Exit
#
# Please enter Y to edit student details or N to quit : y
# Please choose your operation command : 1
# Please choose your operation command : 1
# Please choose your operation command : 2
#
#
#
# List Of Students
# Name  :  Ada
# Age  :  18
# Gender  :  F
# Dob  :  20140628
# Seatno  :  1
#
#
# Name  :  Sophia
# Age  :  20
# Gender  :  F
# Dob  :  19980114
# Seatno  :  2
#
#
# Name  :  Peter
# Age  :  21
# Gender  :  M
# Dob  :  19990628
# Seatno  :  3
#
#
# Name  :  Clement
# Age  :  21
# Gender  :  M
# Dob  :  19900624
# Seatno  :  4
#
#
# Name  :  Ada
# Age  :  18
# Gender  :  F
# Dob  :  20140628
# Seatno  :  1
#
#
# Name  :  Sophia
# Age  :  20
# Gender  :  F
# Dob  :  19980114
# Seatno  :  2
#
#
# Name  :  Peter
# Age  :  21
# Gender  :  M
# Dob  :  19990628
# Seatno  :  3
#
#
# Name  :  Clement
# ...

# %% [markdown]
# #
